# %% [markdown]
# # Airbnb Calendar Data - EDA

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/calendar.csv')

# %%
df
# Out:
#                   listing_id        date available    price adjusted_price  \
# 0                        109  2023-09-04         f  $129.00        $129.00
# 1                        109  2023-09-05         f  $129.00        $129.00
# 2                        109  2023-09-06         f  $129.00        $129.00
# 3                        109  2023-09-07         f  $129.00        $129.00
# 4                        109  2023-09-08         f  $129.00        $129.00
# ...                      ...         ...       ...      ...            ...
# 16276420  972398639579333846  2024-08-29         f  $425.00        $425.00
# 16276421  972398639579333846  2024-08-30         f  $425.00        $425.00
# 16276422  972398639579333846  2024-08-31         f  $425.00        $425.00
# 16276423  972398639579333846  2024-09-01         f  $425.00        $425.00
# 16276424  972398639579333846  2024-09-02         f  $425.00        $425.00
#
#           minimum_nights  maximum_nights
# ...

# %%
df[df['listing_id'] == 109][0:30]
# Out:
#     listing_id        date available    price adjusted_price  minimum_nights  \
# 0          109  2023-09-04         f  $129.00        $129.00            30.0
# 1          109  2023-09-05         f  $129.00        $129.00            30.0
# 2          109  2023-09-06         f  $129.00        $129.00            30.0
# 3          109  2023-09-07         f  $129.00        $129.00            30.0
# 4          109  2023-09-08         f  $129.00        $129.00            30.0
# 5          109  2023-09-09         f  $129.00        $129.00            30.0
# 6          109  2023-09-10         f  $129.00        $129.00            30.0
# 7          109  2023-09-11         f  $129.00        $129.00            30.0
# 8          109  2023-09-12         f  $129.00        $129.00            30.0
# 9          109  2023-09-13         f  $129.00        $129.00            30.0
# 10         109  2023-09-14         f  $129.00        $129.00            30.0
# ...
