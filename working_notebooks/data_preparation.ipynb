# %% [markdown]
# # Data Preparation & Text Pre-Processing

# %% [markdown]
# ## Overview

# %% [markdown]
# I have been contracted by a boutique real estate firm out of Manhattan Beach California to help them optimize the Airbnb branch of their business. With hundreds of properties across Los Angeles, this firm wants to ensure that they are maximizing return on each of their properties by setting an optimal per night price point. With detailed information numerous written reviews for each of their properties, they wish to uncover whether these written reviews along with other can be used to set optimal price points.

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# To perform this analysis, I have chosen to use Natural Language Processing (NLP) to build a classification model to explore whether Airbnb written reviews are reliable predictors for the ‘price per night’ of a given Airbnb listing. Specifically, for one bedroom listings as they occupy the majority of Airbnb listings in the greater Los Angeles. Based on the results, this analysis will aim to communicate clear recommendations on how to utilize this model to optimize Airbnb price listing strategy.

# %% [markdown]
# ## The Data

# %% [markdown]
# The data for this analysis was pulled from Inside Airbnb. The two data sets used include detailed information such as 'price', 'number of bedrooms', 'neighborhoods' from 44,000 Airbnb listings in greater Los Angeles as well as their corresponding written reviews. In the "Data Preprocessing" section below we will merge these two data sets and filter them down to the features on interest.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# We'll start with importing the relevant packages:

# %%
# Imports
import pandas as pd
import numpy as np
import nltk
nltk.download('stopwords')


from nltk.tokenize import RegexpTokenizer, word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.probability import FreqDist
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score, cross_val_predict, cross_validate
from tqdm import tqdm
# Out:
# [nltk_data] Downloading package stopwords to /Users/jf/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Load in Los Angeles 'Listings' & 'Reviews'

# %%
# load in rviews and listings data
la_rev = pd.read_csv('../data/la_reviews.csv')
la_list = pd.read_csv('../data/la_listings.csv')

# %% [markdown]
# ## 1. 'Reviews' Cleaning & EDA
#
# We'll begin by exploring and cleaning the Airbnb reviews data frame to prepare it for Natural Language Processing (NLP).

# %%
# take a look at first few rows of data set
la_rev.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0     8941071   68391055  2016-04-04     10164333        Smruti
# 1     8941071  153719836  2017-05-21     97944097           Rob
# 2     8941071  147589354  2017-04-27      4123723         Widya
# 3     8941071  145742425  2017-04-19      1459499        Darian
# 4     8941071  144400833  2017-04-15     98494277       Charlie
#
#                                             comments
# 0  Danielle was a great host, she was extremely r...
# 1  The apartment was great for us to spend the we...
# 2  Danielle is a great host, very concerned  with...
# 3  Great location and spacious. Danielle's place ...
# 4  Danielle's place was as expected, really good ...

# %% [markdown]
# **Here we see that each Airbnb listing has it's ```reviews``` split up into individual entries (rows). We will have to group all reviews by their respective listings**

# %%
# quick breakdown of the data set
la_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1532925 entries, 0 to 1532924
# Data columns (total 6 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   listing_id     1532925 non-null  int64
#  1   id             1532925 non-null  int64
#  2   date           1532925 non-null  object
#  3   reviewer_id    1532925 non-null  int64
#  4   reviewer_name  1532925 non-null  object
#  5   comments       1532639 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 70.2+ MB

# %% [markdown]
# ### Handling null values
# We decide to drop all null values as there are only 286 in a data set of over 1.5 million rows.

# %%
# checking for nulls
la_rev['comments'].isna().sum()
# Out:
# 286

# %%
# visualizing nulls
la_rev[la_rev['comments'].isna()]
# Out:
#                  listing_id                  id        date  reviewer_id  \
# 11041              12232198           597570153  2020-01-25    109869097
# 36262              18771571           499592244  2019-07-31    200662007
# 38689              19966810           428734333  2019-03-25    248109683
# 39068              20012997  500736816306141481  2021-11-21     78355861
# 40846              19434972  486204261023070433  2021-11-01    110160469
# ...                     ...                 ...         ...          ...
# 1511887            16661893           621560353  2020-04-01    342670536
# 1514989            46444583  868264023745043602  2023-04-12     23149537
# 1517560            19332411           222064868  2017-12-28    113707624
# 1524215            30460122           561530122  2019-11-09    207881679
# 1528644  759306265762146686  803005517846458209  2023-01-12      9721087
#
#         reviewer_name comments
# 11041           Larry      NaN
# 36262          Lilyan      NaN
# 38689        Danielle      NaN
# 39068            Jill      NaN
# 40846          Farnaz      NaN
# ...               ...      ...
# 1511887            Al      NaN
# 1514989      Flannery      NaN
# 1517560         Betsy      NaN
# 1524215        Bianca      NaN
# 1528644           Joy      NaN
#
# [286 rows x 6 columns]

# %%
# dropping null values
la_rev.dropna(subset=['comments'], inplace=True)

# %%
# sanity check
la_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1532639 entries, 0 to 1532924
# Data columns (total 6 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   listing_id     1532639 non-null  int64
#  1   id             1532639 non-null  int64
#  2   date           1532639 non-null  object
#  3   reviewer_id    1532639 non-null  int64
#  4   reviewer_name  1532639 non-null  object
#  5   comments       1532639 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 81.9+ MB

# %% [markdown]
# ### Grouping reviews by listing_id
# Now that null values have been handled we need to group all the comments by listing_id. Not only is this a necessary step for NLP but, it will also shrink our data set which will make training models less time consuming.
#
# As a sanity check, we check separate reviews for a specific listing_id before grouping all reviews by listing_id.

# %%
# checking separate reviews for a specific 'listing_id' BEFORE grouping
la_rev[la_rev['listing_id'] == 109]
# Out:
#         listing_id        id        date  reviewer_id reviewer_name  \
# 497553         109  74506539  2016-05-15     22509885          Jenn
# 497554         109    449036  2011-08-15       927861         Edwin
#
#                                                  comments
# 497553  Me and two friends stayed for four and a half ...
# 497554  The host canceled my reservation the day befor...

# %%
# grouping all reviews text by 'listing_id'
la_rev_con = la_rev.groupby(['listing_id'], as_index=False).agg({'comments': " ".join})

# %%
# visualize the condensed data frame
la_rev_con
# Out:
#                listing_id                                           comments
# 0                     109  Me and two friends stayed for four and a half ...
# 1                    2708  Charles is the man!! Just wrapped up an amazin...
# 2                    2732  Unfortunately, I was really disappointed with ...
# 3                    6033  Sarah was a great host. She was always quick t...
# 4                    6931  The best host and best stay I've ever had with...
# ...                   ...                                                ...
# 32956  968513441909611726  BEAUTIFUL HOME. GREAT LOCATION. AWESOME SUPER ...
# 32957  969535403681694277  We had a perfect time at Sean’s cottage. It wa...
# 32958  969626715256159808  Kelly was communicative and super responsive. ...
# 32959  970252209631292696  Such a cute spot in a nice neighborhood… check...
# 32960  970335372991144135  Great little spot and a good price. Well worth...
#
# [32961 rows x 2 columns]

# %%
# sanity check: cross-referencing with 'listing_id' 109 above
la_rev_con['comments'][0]
# Out:
# "Me and two friends stayed for four and a half months. It was a great place to stay! The apartment was very comfortable and I really enjoyed having the park with running path across the street. The only downside was it wasn't within walking distance to restaurants, bars, or coffee shops. But they are a short drive away. Overall, great stay! The host canceled my reservation the day before arrival."

# %% [markdown]
# Based on the sanity check above we can see that the 'group by' worked as the separate reviews from ```listing_id 109``` have been grouped in the text above.

# %%
la_rev_con['comments'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## 2. 'Listings' Cleaning & EDA
#
# With a total of 74 features in this data frame, we it narrow it down to our features of interest: **price, bedrooms, bathrooms, neighborhood, written reviews, ratings and property type.**
#
# Seeing as our analysis is primarily focused on one-bedroom lisitngs only, we will filter down our data to include only one bedrooms.
#
# Let's take a look at all of our features as well as potential null values that need to be handled.

# %%
la_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44594 entries, 0 to 44593
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            44594 non-null  int64
#  1   listing_url                                   44594 non-null  object
#  2   scrape_id                                     44594 non-null  int64
#  3   last_scraped                                  44594 non-null  object
#  4   source                                        44594 non-null  object
#  5   name                                          44594 non-null  object
#  6   description                                   43937 non-null  object
#  7   neighborhood_overview                         25053 non-null  object
#  8   picture_url                                   44594 non-null  object
#  9   host_id                                       44594 non-null  int64
#  10  host_url                                      44594 non-null  object
#  11  host_name                                     44592 non-null  object
#  12  host_since                                    44592 non-null  object
#  13  host_location                                 34044 non-null  object
#  14  host_about                                    24684 non-null  object
#  15  host_response_time                            35164 non-null  object
#  16  host_response_rate                            35164 non-null  object
#  17  host_acceptance_rate                          35610 non-null  object
#  18  host_is_superhost                             43515 non-null  object
#  19  host_thumbnail_url                            44592 non-null  object
#  20  host_picture_url                              44592 non-null  object
#  21  host_neighbourhood                            34730 non-null  object
#  22  host_listings_count                           44592 non-null  float64
#  23  host_total_listings_count                     44592 non-null  float64
#  24  host_verifications                            44594 non-null  object
#  25  host_has_profile_pic                          44592 non-null  object
#  26  host_identity_verified                        44592 non-null  object
#  27  neighbourhood                                 25054 non-null  object
#  28  neighbourhood_cleansed                        44594 non-null  object
#  29  neighbourhood_group_cleansed                  44594 non-null  object
#  30  latitude                                      44594 non-null  float64
#  31  longitude                                     44594 non-null  float64
#  32  property_type                                 44594 non-null  object
#  33  room_type                                     44594 non-null  object
#  34  accommodates                                  44594 non-null  int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                44569 non-null  object
#  37  bedrooms                                      31251 non-null  float64
#  38  beds                                          44091 non-null  float64
#  39  amenities                                     44594 non-null  object
#  40  price                                         44594 non-null  object
#  41  minimum_nights                                44594 non-null  int64
#  42  maximum_nights                                44594 non-null  int64
#  43  minimum_minimum_nights                        44594 non-null  int64
#  44  maximum_minimum_nights                        44594 non-null  int64
#  45  minimum_maximum_nights                        44594 non-null  int64
#  46  maximum_maximum_nights                        44594 non-null  int64
#  47  minimum_nights_avg_ntm                        44594 non-null  float64
#  48  maximum_nights_avg_ntm                        44594 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              44594 non-null  object
#  51  availability_30                               44594 non-null  int64
#  52  availability_60                               44594 non-null  int64
#  53  availability_90                               44594 non-null  int64
#  54  availability_365                              44594 non-null  int64
#  55  calendar_last_scraped                         44594 non-null  object
#  56  number_of_reviews                             44594 non-null  int64
#  57  number_of_reviews_ltm                         44594 non-null  int64
#  58  number_of_reviews_l30d                        44594 non-null  int64
#  59  first_review                                  32962 non-null  object
#  60  last_review                                   32962 non-null  object
#  61  review_scores_rating                          32962 non-null  float64
#  62  review_scores_accuracy                        32731 non-null  float64
#  63  review_scores_cleanliness                     32732 non-null  float64
#  64  review_scores_checkin                         32724 non-null  float64
#  65  review_scores_communication                   32731 non-null  float64
#  66  review_scores_location                        32723 non-null  float64
#  67  review_scores_value                           32720 non-null  float64
#  68  license                                       11552 non-null  object
#  69  instant_bookable                              44594 non-null  object
#  70  calculated_host_listings_count                44594 non-null  int64
#  71  calculated_host_listings_count_entire_homes   44594 non-null  int64
#  72  calculated_host_listings_count_private_rooms  44594 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   44594 non-null  int64
#  74  reviews_per_month                             32962 non-null  float64
# dtypes: float64(18), int64(21), object(36)
# memory usage: 25.5+ MB

# %%
# condensing df to potential features of interest for modeling
la_small = la_list[['id', 'price', 'bedrooms', 'neighbourhood_cleansed', 
                    'minimum_nights', 'maximum_nights', 'property_type', 'bathrooms_text', 'review_scores_rating',
                    'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 
                    'review_scores_communication', 'review_scores_location', 'review_scores_value']]

# %%
# Filtering for 1 bedroom properties - Analysis only concerned with 1 bedroom Airbnb listings
df_la_1bd = la_small[la_small['bedrooms'] == 1.0]

# %% [markdown]
# ### Cleaning ```price``` feature - target variable

# %%
# removing decimals from price points
df_la_1bd['price'] = df_la_1bd['price'].str.split('.').str[0]

# removing commas from price points
df_la_1bd['price'] = df_la_1bd['price'].str.replace(",", "")

# removing $ signs from price points
df_la_1bd['price'] = df_la_1bd['price'].str.replace('$', '')

# convert price to 'int'
df_la_1bd['price'] = df_la_1bd['price'].astype(int)

df_la_1bd['price']
# Out:
# <ipython-input-34-8d33783b4058>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_la_1bd['price'] = df_la_1bd['price'].str.split('.').str[0]
# <ipython-input-34-8d33783b4058>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_la_1bd['price'] = df_la_1bd['price'].str.replace(",", "")
# <ipython-input-34-8d33783b4058>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_la_1bd['price'] = df_la_1bd['price'].str.replace('$', '')
# <ipython-input-34-8d33783b4058>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_la_1bd['price'] = df_la_1bd['price'].astype(int)
# 2         69
# 3        120
# 8        201
# 11        88
# 15        60
#         ...
# 44586    175
# 44587    194
# 44588    180
# 44590    168
# 44593    480
# Name: price, Length: 13791, dtype: int64

# %% [markdown]
# ### Cleaning ```bathrooms_text``` column:

# %% [markdown]
# We decide to drop text values and incorrect entries as they account for a small number of listings out of the 13,000 total listings.

# %%
df_la_1bd['bathrooms_text'].value_counts()
# Out:
# 1            13074
# 1.5            419
# 2              231
# Half-bath       35
# 2.5             18
# 11              16
# 0               16
# 3               13
# 6               11
# 3.5             11
# Shared           9
# 4                6
# Private          2
# 8                1
# 11.5             1
# Name: bathrooms_text, dtype: int64

# %%
# select for only numbers in bathrooms column
df_la_1bd['bathrooms_text'] = df_la_1bd['bathrooms_text'].str.split(" ").str[0]

# drop text and incorrect entries
b = ['4', '6', '8', '11', '11.5', 'Half-bath', 'Private', 'Shared']
bathroom_drop = df_la_1bd[df_la_1bd['bathrooms_text'].isin(b)].index
df_la_1bd.drop(bathroom_drop, inplace=True)

# asign 'float_type' to 'bathrooms_text'
df_la_1bd['bathrooms_text'].astype(float)
# Out:
# <ipython-input-29-bb93b37c023a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_la_1bd['bathrooms_text'] = df_la_1bd['bathrooms_text'].str.split(" ").str[0]
# 2        1.0
# 3        1.5
# 8        1.0
# 11       1.0
# 15       1.0
#         ...
# 44586    1.0
# 44587    1.0
# 44588    1.0
# 44590    1.0
# 44593    1.0
# Name: bathrooms_text, Length: 13791, dtype: float64

# %% [markdown]
# ### Cleaning ```property_type``` column:

# %%
# breakdown the various property types
df_la_1bd['property_type'].value_counts()[0:30]
# Out:
# Entire rental unit                    6362
# Entire guesthouse                     1522
# Entire home                           1392
# Entire guest suite                     859
# Entire condo                           757
# Private room in home                   424
# Room in hotel                          307
# Entire bungalow                        263
# Entire serviced apartment              254
# Entire loft                            236
# Private room in rental unit            221
# Room in boutique hotel                 217
# Camper/RV                              113
# Private room in guesthouse              93
# Tiny home                               87
# Entire cottage                          81
# Entire townhouse                        75
# Private room in guest suite             57
# Private room in loft                    52
# Private room in serviced apartment      40
# Entire place                            39
# Room in aparthotel                      37
# Private room in condo                   37
# Private room in townhouse               35
# Entire vacation home                    27
# Entire cabin                            24
# Entire villa                            18
# Private room in villa                   16
# Private room in hostel                  16
# Farm stay                               10
# Name: property_type, dtype: int64

# %% [markdown]
# The property types above can obviously be cleaned up and condensed. Any type of 'private room' can be grouped, any 'Entire' unit can be grouped and any 'suite' can aslo be grouped.

# %%
# create function to condense property types
def transform_accommodation_type(val):
    if "room" in val:
        return "Private Room"
    elif "suite" in val:
        return "Guest Suite"
    elif "Entire" in val:
        return "Entire Unit"
    else:
        return "Other"

df_la_1bd['property_type'] = df_la_1bd['property_type'].apply(transform_accommodation_type)

# sanity checkl
df_la_1bd['property_type'].value_counts()
# Out:
# <ipython-input-31-9e56933ccf12>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_la_1bd['property_type'] = df_la_1bd['property_type'].apply(transform_accommodation_type)
# Entire Unit     11056
# Private Room     1047
# Guest Suite       859
# Other             829
# Name: property_type, dtype: int64

# %% [markdown]
# ## Merge 'Reviews' and 'Listings'
# Now that we have cleaned both data frames, it is time to merge them into a single data frame. Specifically, an inner meger in this case as we only want lisitngs that appear in both data frames so that all lisitngs in the merged data frame will have corresponding reviews.

# %%
# merge 'reviews' df with filtered 'listings' df
df_merge = df_la_1bd.merge(la_rev_con, how='inner', left_on='id', right_on='listing_id')
df_merge
# Out:
#                       id  price  bedrooms neighbourhood_cleansed  \
# 0               41240375    120       1.0          Playa del Rey
# 1               15239926    201       1.0          Santa Clarita
# 2               14821183     88       1.0            Diamond Bar
# 3               26296415    180       1.0               Torrance
# 4               22746714     35       1.0         North El Monte
# ...                  ...    ...       ...                    ...
# 9823  575384126844892676    159       1.0         West Hollywood
# 9824            16072625    177       1.0         East Hollywood
# 9825  924091269757225413    120       1.0          Beverly Hills
# 9826  720164781296601135    175       1.0         West Hollywood
# 9827  680301812424175952    180       1.0               Downtown
#
#       minimum_nights  maximum_nights property_type bathrooms_text  \
# 0                 30            1125   Entire Unit            1.5
# 1                  2              30         Other              1
# 2                  1            1125  Private Room              1
# 3                  1            1125   Entire Unit              1
# 4                  1            1125  Private Room              1
# ...              ...             ...           ...            ...
# 9823              31            1125   Entire Unit              1
# 9824              31              92   Entire Unit              1
# 9825               1              28   Entire Unit              1
# 9826               2            1125   Entire Unit              1
# 9827              30             365   Entire Unit              1
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                     5.00                    5.00                       5.00
# 1                     4.99                    4.98                       5.00
# 2                     3.00                    4.00                       2.00
# 3                     5.00                    5.00                       5.00
# 4                     4.57                    5.00                       4.57
# ...                    ...                     ...                        ...
# 9823                  4.67                    4.67                       5.00
# 9824                  4.14                    4.57                       4.29
# 9825                  1.00                    1.00                       1.00
# 9826                  4.75                    4.75                       4.50
# 9827                  4.50                    5.00                       5.00
#
#       review_scores_checkin  review_scores_communication  \
# 0                      5.00                         5.00
# 1                      4.99                         5.00
# 2                      5.00                         5.00
# 3                      5.00                         5.00
# 4                      4.71                         4.43
# ...                     ...                          ...
# 9823                   4.67                         5.00
# 9824                   4.86                         4.43
# 9825                   1.00                         1.00
# 9826                   4.50                         4.25
# 9827                   5.00                         4.50
#
#       review_scores_location  review_scores_value          listing_id  \
# 0                       5.00                 5.00            41240375
# 1                       4.97                 4.86            15239926
# 2                       4.00                 3.00            14821183
# 3                       5.00                 5.00            26296415
# 4                       4.43                 4.71            22746714
# ...                      ...                  ...                 ...
# 9823                    4.00                 3.33  575384126844892676
# 9824                    4.43                 3.86            16072625
# 9825                    5.00                 1.00  924091269757225413
# 9826                    5.00                 4.75  720164781296601135
# 9827                    5.00                 4.50  680301812424175952
#
#                                                comments
# 0     Paola is the best host I have ever had. She ha...
# 1     Fantastic super hosts and space . What a beaut...
# 2     Quiet house. Bedroom is enough for sleeping. u...
# 3     Amazing experience. The house was also recentl...
# 4     Nice neighborhood and hosts. Great location. T...
# ...                                                 ...
# 9823  Super host, thank you! This apartment was perf...
# 9824  Great location. And overall a decent stay. My ...
# 9825  Since they sent me a review, I guess I’m revie...
# 9826  Great location, great host, beautiful apartmen...
# 9827  Very convenient and comfortable. It had everyt...
#
# [9828 rows x 17 columns]

# %% [markdown]
# Good practice is to check for null values after merging two data frames.

# %%
#checking for nulls in reviews
df_merge.isna().sum()
# Out:
# id                              0
# price                           0
# bedrooms                        0
# neighbourhood_cleansed          0
# minimum_nights                  0
# maximum_nights                  0
# property_type                   0
# bathrooms_text                  3
# review_scores_rating            0
# review_scores_accuracy         59
# review_scores_cleanliness      58
# review_scores_checkin          60
# review_scores_communication    58
# review_scores_location         61
# review_scores_value            61
# listing_id                      0
# comments                        0
# dtype: int64

# %%
# dropping nulls from reviews
df_merge.dropna(inplace=True)

# sanity check
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9763 entries, 0 to 9827
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           9763 non-null   int64
#  1   price                        9763 non-null   int64
#  2   bedrooms                     9763 non-null   float64
#  3   neighbourhood_cleansed       9763 non-null   object
#  4   minimum_nights               9763 non-null   int64
#  5   maximum_nights               9763 non-null   int64
#  6   property_type                9763 non-null   object
#  7   bathrooms_text               9763 non-null   object
#  8   review_scores_rating         9763 non-null   float64
#  9   review_scores_accuracy       9763 non-null   float64
#  10  review_scores_cleanliness    9763 non-null   float64
#  11  review_scores_checkin        9763 non-null   float64
#  12  review_scores_communication  9763 non-null   float64
#  13  review_scores_location       9763 non-null   float64
#  14  review_scores_value          9763 non-null   float64
#  15  listing_id                   9763 non-null   int64
#  16  comments                     9763 non-null   object
# dtypes: float64(8), int64(5), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Dropping 'Long-Term' Stays

# %% [markdown]
# By looking ay the ```minimum_nights``` column, we notice that some lisitngs required a 30-night minimum stay, indictaing that these are long-term or monthly rentals. We also notice that the corresponding ```price``` for these rentals are for a monthly rate and not a per night rate. As a result, we drop these 'long-term' listings.

# %%
# drop long term stays
longterm_stays = df_merge[df_merge['minimum_nights'] >= 30].index
df_merge.drop(longterm_stays, inplace=True)
df_merge
# Out:
#                       id  price  bedrooms neighbourhood_cleansed  \
# 1               15239926    201       1.0          Santa Clarita
# 2               14821183     88       1.0            Diamond Bar
# 3               26296415    180       1.0               Torrance
# 4               22746714     35       1.0         North El Monte
# 6               52992116    200       1.0            Silver Lake
# ...                  ...    ...       ...                    ...
# 9818  593563874468145823     50       1.0         South El Monte
# 9819            16134682    186       1.0         West Hollywood
# 9822            45361780    134       1.0              Hawthorne
# 9825  924091269757225413    120       1.0          Beverly Hills
# 9826  720164781296601135    175       1.0         West Hollywood
#
#       minimum_nights  maximum_nights property_type bathrooms_text  \
# 1                  2              30         Other              1
# 2                  1            1125  Private Room              1
# 3                  1            1125   Entire Unit              1
# 4                  1            1125  Private Room              1
# 6                  2              30   Guest Suite              1
# ...              ...             ...           ...            ...
# 9818               5             365  Private Room            1.5
# 9819               2              10   Entire Unit              1
# 9822               1              26   Entire Unit              1
# 9825               1              28   Entire Unit              1
# 9826               2            1125   Entire Unit              1
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 1                     4.99                    4.98                       5.00
# 2                     3.00                    4.00                       2.00
# 3                     5.00                    5.00                       5.00
# 4                     4.57                    5.00                       4.57
# 6                     5.00                    5.00                       5.00
# ...                    ...                     ...                        ...
# 9818                  4.86                    4.86                       5.00
# 9819                  5.00                    5.00                       5.00
# 9822                  4.90                    4.89                       4.75
# 9825                  1.00                    1.00                       1.00
# 9826                  4.75                    4.75                       4.50
#
#       review_scores_checkin  review_scores_communication  \
# 1                      4.99                         5.00
# 2                      5.00                         5.00
# 3                      5.00                         5.00
# 4                      4.71                         4.43
# 6                      4.97                         5.00
# ...                     ...                          ...
# 9818                   5.00                         4.57
# 9819                   5.00                         5.00
# 9822                   4.91                         4.95
# 9825                   1.00                         1.00
# 9826                   4.50                         4.25
#
#       review_scores_location  review_scores_value          listing_id  \
# 1                       4.97                 4.86            15239926
# 2                       4.00                 3.00            14821183
# 3                       5.00                 5.00            26296415
# 4                       4.43                 4.71            22746714
# 6                       5.00                 5.00            52992116
# ...                      ...                  ...                 ...
# 9818                    4.57                 4.86  593563874468145823
# 9819                    5.00                 5.00            16134682
# 9822                    4.73                 4.74            45361780
# 9825                    5.00                 1.00  924091269757225413
# 9826                    5.00                 4.75  720164781296601135
#
#                                                comments
# 1     Fantastic super hosts and space . What a beaut...
# 2     Quiet house. Bedroom is enough for sleeping. u...
# 3     Amazing experience. The house was also recentl...
# 4     Nice neighborhood and hosts. Great location. T...
# 6     Everything was great! The room was nice and cl...
# ...                                                 ...
# 9818  Great place, good communication and excellent ...
# 9819  Bella’s place is everything you see on the pic...
# 9822  The place was exactly how the owner described ...
# 9825  Since they sent me a review, I guess I’m revie...
# 9826  Great location, great host, beautiful apartmen...
#
# [5258 rows x 17 columns]

# %% [markdown]
# Though we have dropped long-term stays in ```minimum_nights```, we notice that ```price``` carries a few outliers. By digging into these listings on airbnb.com, we find that they are incorrectly priced (monthly rate instead of per night rate). We drop these as well.

# %%
df_merge['price'].describe()
# Out:
# count     5258.000000
# mean       223.465196
# std       1905.944137
# min         10.000000
# 25%        110.000000
# 50%        149.000000
# 75%        199.000000
# max      99999.000000
# Name: price, dtype: float64

# %%
df_merge[df_merge['price'] >= 999]
# Out:
#                       id  price  bedrooms neighbourhood_cleansed  \
# 139             35843831   9999       1.0            Studio City
# 143             35843690   9999       1.0            Studio City
# 533             37557082   1500       1.0                 Malibu
# 679             52619433   3130       1.0               Glendale
# 713   812386491863587915   9999       1.0               Pasadena
# 1188  812389869434454826   9999       1.0               Pasadena
# 1278            35633263   9999       1.0            Studio City
# 1842            38755677   5000       1.0         Universal City
# 1973            18979304  99999       1.0          Beverly Hills
# 2684            19769097   9999       1.0          Beverly Hills
# 3857            39029905   1120       1.0           Santa Monica
# 4636            35636956   9999       1.0            Studio City
# 6009             3710503   2000       1.0                Burbank
# 6622  836719720031304955  10000       1.0                 Venice
# 6887  836723662331951033  10000       1.0                 Venice
# 7080  734690224784390246   2000       1.0                 Venice
# 7684  836725106298539007  10000       1.0                 Venice
# 8595  646443170780535642   1262       1.0         West Hollywood
# 8949  546483898096607267  90150       1.0           West Compton
#
#       minimum_nights  maximum_nights property_type bathrooms_text  \
# 139                1            1125         Other              1
# 143                1            1125         Other              1
# 533                7            1125   Entire Unit              1
# 679                2             365   Entire Unit              1
# 713                1            1125  Private Room              1
# 1188               1            1125  Private Room              1
# 1278               1            1125         Other              1
# 1842               1              28   Entire Unit              1
# 1973               1            1125   Entire Unit              1
# 2684               1            1125  Private Room              1
# 3857               1              28         Other              1
# 4636               1            1125         Other              1
# 6009               1            1125   Entire Unit            1.5
# 6622               1             365         Other              1
# 6887               1            1125         Other              1
# 7080               2              30   Entire Unit              2
# 7684               1            1125         Other              1
# 8595              18            1125   Entire Unit              1
# 8949               2               7   Entire Unit              1
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 139                   5.00                    5.00                       5.00
# 143                   1.00                    1.00                       1.00
# 533                   5.00                    5.00                       5.00
# 679                   4.33                    4.58                       4.50
# 713                   5.00                    5.00                       5.00
# 1188                  5.00                    2.00                       5.00
# 1278                  5.00                    5.00                       5.00
# 1842                  4.95                    4.95                       4.84
# 1973                  4.98                    5.00                       4.88
# 2684                  4.95                    4.95                       4.95
# 3857                  1.00                    1.00                       1.00
# 4636                  5.00                    5.00                       5.00
# 6009                  5.00                    5.00                       5.00
# 6622                  4.78                    4.81                       4.78
# 6887                  4.70                    4.74                       4.79
# 7080                  5.00                    5.00                       5.00
# 7684                  4.67                    4.72                       4.75
# 8595                  5.00                    5.00                       5.00
# 8949                  5.00                    5.00                       4.93
#
#       review_scores_checkin  review_scores_communication  \
# 139                    5.00                         5.00
# 143                    1.00                         1.00
# 533                    5.00                         5.00
# 679                    4.17                         4.42
# 713                    5.00                         5.00
# 1188                   2.00                         5.00
# 1278                   5.00                         5.00
# 1842                   4.89                         5.00
# 1973                   4.98                         5.00
# 2684                   5.00                         5.00
# 3857                   1.00                         1.00
# 4636                   5.00                         5.00
# 6009                   5.00                         5.00
# 6622                   4.75                         4.78
# 6887                   4.79                         4.77
# 7080                   4.00                         5.00
# 7684                   4.78                         4.92
# 8595                   5.00                         5.00
# 8949                   5.00                         5.00
#
#       review_scores_location  review_scores_value          listing_id  \
# 139                     5.00                 5.00            35843831
# 143                     5.00                 1.00            35843690
# 533                     4.71                 4.86            37557082
# 679                     4.92                 4.58            52619433
# 713                     5.00                 5.00  812386491863587915
# 1188                    5.00                 3.00  812389869434454826
# 1278                    5.00                 5.00            35633263
# 1842                    5.00                 4.79            38755677
# 1973                    5.00                 4.89            18979304
# 2684                    5.00                 4.90            19769097
# 3857                    1.00                 1.00            39029905
# 4636                    5.00                 4.00            35636956
# 6009                    5.00                 5.00             3710503
# 6622                    4.84                 4.38  836719720031304955
# 6887                    4.83                 4.45  836723662331951033
# 7080                    5.00                 5.00  734690224784390246
# 7684                    4.83                 4.47  836725106298539007
# 8595                    5.00                 5.00  646443170780535642
# 8949                    5.00                 5.00  546483898096607267
#
#                                                comments
# 139                        Great time here. Thanks guys
# 143   Overpriced and overrated. If you’re bringing y...
# 533   What a great place! Peaceful, beautiful and ho...
# 679   Dymund was great!! Place was nice and clean ev...
# 713   Great stay! Really spacious for my partner and...
# 1188  The room is in a hotel, and the photos on AirB...
# 1278                                   Wonderful place!
# 1842  Alex along with his place were very nice! Alex...
# 1973  We appreciated the accommodations during our r...
# 2684  Great location and Sugar (the worlds sweetest ...
# 3857  DO NOT STAY HERE! I am an avid traveler and us...
# 4636                          Always good to stay there
# 6009                 Great location, very accommodating
# 6622  It’s was a nice clean hotel the service was am...
# 6887  A perfect place in Venice ! In middle of every...
# 7080  Amazing place for a romantic getaway. Unbeliev...
# 7684  I booked this room last minute and it exceeded...
# 8595  Kaylin and Matt were great hosts! Had a wonder...
# 8949  Fantastic spot Terrence and Nancy were very ni...

# %%
#drop long term stays - any listings over $999 per night correspond to longterm stays
longterm_stays = df_merge[df_merge['price'] >= 999].index
df_merge.drop(longterm_stays, inplace=True)

# %% [markdown]
# ### Converting Tagret Variable ```Price``` to Discrete
# Seeing as this is a classification analysis we need to convert our ```price``` target variable to a discrte varaible. We achieve by creating classes: ranges of price points. Specifically weuse the inter quartile range (IQR) to ditinguish our classes.

# %%
df_processed_out['price'].describe()

# %%
#create a column that sorts price based on categories of ranges of price
conditions = [
    (df_merge['price'] <= 109),
    (df_merge['price'] > 109) & (df_merge['price'] <= 148),
    (df_merge['price'] > 148) & (df_merge['price'] <= 199),
    (df_merge['price'] > 199)]

#create a list of the values we want to assign for each condition
values = [0, 1, 2, 3]

#create a new column and use np.select to assign values to it using our lists as arguments
df_merge['price_range'] = np.select(conditions, values)
df_merge

# %% [markdown]
# Now that we have a merged and cleaned data set let's move on to the fun part...**text processing**!

# %% [markdown]
# ## Text Pre-Processing

# %% [markdown]
# An essential task in Natural-Language-Processing is to sort through the text, essentially whittling it down to it key components.
#
# Steps:
#
# 1. **Special Character Removal**: Eliminates non-alphabetic characters to make the text more uniform.
# 2. **Case Normalization**: Converts all text to lowercase to neutralize case sensitivity.
# 3. **Tokenization**: Breaks the text into individual words for easier manipulation.
# 4. **Word Length Filtering**: Removes words that are too short and are likely to be irrelevant.
# 5. **Stopword Removal**: Filters out commonly-used words that usually don't contribute to the meaning of a sentence.
# 6. **POS Tagging and Lemmatization**: Assigns Parts of Speech (POS) tags and reduces words to their base or root form.

# %% [markdown]
# ### Pre-Process Function:

# %%
# instantiate tokenizer
# regex pattern returns words or 3 or more characters and drops all non-english characters
token_pattern = r"(?u)\w{3,}|/[^\x00-\x7F]+/"
tokenizer = RegexpTokenizer(token_pattern)

# create a list of stopwords
stopwords_list = stopwords.words('english')

# %%
# create function to pre-process text
def preprocess_text(text, tokenizer, stopwords_list):
    # Standardize case (lowercase the text)
    text_std = text.lower()
    # Tokenize
    token_list = tokenizer.tokenize(text_std)
    # Remove stopwords
    stopwords_removed = [token for token in token_list if token not in stopwords_list]
    return stopwords_removed

# %%
# pre-process the text data using the 'preprocess_text' function
reviews_proc = df_merge.comments.apply(lambda x: preprocess_text(x, tokenizer, stopwords_list))
reviews_proc
# Out:
# 1       [fantastic, super, hosts, space, beautiful, pl...
# 2       [quiet, house, bedroom, enough, sleeping, uncl...
# 3       [amazing, experience, house, also, recently, u...
# 4       [nice, neighborhood, hosts, great, location, h...
# 6       [everything, great, room, nice, clean, describ...
#                               ...
# 9818    [great, place, good, communication, excellent,...
# 9819    [bella, place, everything, see, pictures, bett...
# 9822    [place, exactly, owner, described, beautiful, ...
# 9825    [since, sent, review, guess, reviewing, confir...
# 9826    [great, location, great, host, beautiful, apar...
# Name: comments, Length: 5239, dtype: object

# %% [markdown]
# ### Tag & Lemmatize:

# %%
#Create Lemmatizer
lemmatizer = WordNetLemmatizer()

#Map POS tag to first character for use in WordNetLemmatizer
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # Default to NOUN
    
#POS Tagging
tagged_text = reviews_proc.apply(lambda x: pos_tag(x))
tagged_text

#Lemmatize the processed text
processed_rev = tagged_text.apply(lambda x: [lemmatizer.lemmatize(word, get_wordnet_pos(pos)) for word, pos in x])

#create new column in df with the processed reviews
df_merge['processed_reviews'] = processed_rev
df_merge

#convert token lists to strings
df_merge['processed_reviews'] = df_merge['processed_reviews'].str.join(' ')
df_merge
# Out:
#                       id  price  bedrooms neighbourhood_cleansed  \
# 1               15239926    201       1.0          Santa Clarita
# 2               14821183     88       1.0            Diamond Bar
# 3               26296415    180       1.0               Torrance
# 4               22746714     35       1.0         North El Monte
# 6               52992116    200       1.0            Silver Lake
# ...                  ...    ...       ...                    ...
# 9818  593563874468145823     50       1.0         South El Monte
# 9819            16134682    186       1.0         West Hollywood
# 9822            45361780    134       1.0              Hawthorne
# 9825  924091269757225413    120       1.0          Beverly Hills
# 9826  720164781296601135    175       1.0         West Hollywood
#
#       minimum_nights  maximum_nights property_type bathrooms_text  \
# 1                  2              30         Other              1
# 2                  1            1125  Private Room              1
# 3                  1            1125   Entire Unit              1
# 4                  1            1125  Private Room              1
# 6                  2              30   Guest Suite              1
# ...              ...             ...           ...            ...
# 9818               5             365  Private Room            1.5
# 9819               2              10   Entire Unit              1
# 9822               1              26   Entire Unit              1
# 9825               1              28   Entire Unit              1
# 9826               2            1125   Entire Unit              1
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 1                     4.99                    4.98                       5.00
# 2                     3.00                    4.00                       2.00
# 3                     5.00                    5.00                       5.00
# 4                     4.57                    5.00                       4.57
# 6                     5.00                    5.00                       5.00
# ...                    ...                     ...                        ...
# 9818                  4.86                    4.86                       5.00
# 9819                  5.00                    5.00                       5.00
# 9822                  4.90                    4.89                       4.75
# 9825                  1.00                    1.00                       1.00
# 9826                  4.75                    4.75                       4.50
#
#       review_scores_checkin  review_scores_communication  \
# 1                      4.99                         5.00
# 2                      5.00                         5.00
# 3                      5.00                         5.00
# 4                      4.71                         4.43
# 6                      4.97                         5.00
# ...                     ...                          ...
# 9818                   5.00                         4.57
# 9819                   5.00                         5.00
# 9822                   4.91                         4.95
# 9825                   1.00                         1.00
# 9826                   4.50                         4.25
#
#       review_scores_location  review_scores_value          listing_id  \
# 1                       4.97                 4.86            15239926
# 2                       4.00                 3.00            14821183
# 3                       5.00                 5.00            26296415
# 4                       4.43                 4.71            22746714
# 6                       5.00                 5.00            52992116
# ...                      ...                  ...                 ...
# 9818                    4.57                 4.86  593563874468145823
# 9819                    5.00                 5.00            16134682
# 9822                    4.73                 4.74            45361780
# 9825                    5.00                 1.00  924091269757225413
# 9826                    5.00                 4.75  720164781296601135
#
#                                                comments  \
# 1     Fantastic super hosts and space . What a beaut...
# 2     Quiet house. Bedroom is enough for sleeping. u...
# 3     Amazing experience. The house was also recentl...
# 4     Nice neighborhood and hosts. Great location. T...
# 6     Everything was great! The room was nice and cl...
# ...                                                 ...
# 9818  Great place, good communication and excellent ...
# 9819  Bella’s place is everything you see on the pic...
# 9822  The place was exactly how the owner described ...
# 9825  Since they sent me a review, I guess I’m revie...
# 9826  Great location, great host, beautiful apartmen...
#
#                                       processed_reviews
# 1     [fantastic, super, host, space, beautiful, pla...
# 2       [quiet, house, bedroom, enough, sleep, unclean]
# 3     [amaze, experience, house, also, recently, upg...
# 4     [nice, neighborhood, host, great, location, ho...
# 6     [everything, great, room, nice, clean, describ...
# ...                                                 ...
# 9818  [great, place, good, communication, excellent,...
# 9819  [bella, place, everything, see, picture, good,...
# 9822  [place, exactly, owner, describe, beautiful, l...
# 9825  [since, send, review, guess, review, confirm, ...
# 9826  [great, location, great, host, beautiful, apar...
#
# [5239 rows x 18 columns]

# %%
#convert token lists to strings
df_merge['processed_reviews'] = df_merge['processed_reviews'].str.join(' ')
df_merge
# Out:
#                       id  price  bedrooms neighbourhood_cleansed  \
# 1               15239926    201       1.0          Santa Clarita
# 2               14821183     88       1.0            Diamond Bar
# 3               26296415    180       1.0               Torrance
# 4               22746714     35       1.0         North El Monte
# 6               52992116    200       1.0            Silver Lake
# ...                  ...    ...       ...                    ...
# 9818  593563874468145823     50       1.0         South El Monte
# 9819            16134682    186       1.0         West Hollywood
# 9822            45361780    134       1.0              Hawthorne
# 9825  924091269757225413    120       1.0          Beverly Hills
# 9826  720164781296601135    175       1.0         West Hollywood
#
#       minimum_nights  maximum_nights property_type bathrooms_text  \
# 1                  2              30         Other              1
# 2                  1            1125  Private Room              1
# 3                  1            1125   Entire Unit              1
# 4                  1            1125  Private Room              1
# 6                  2              30   Guest Suite              1
# ...              ...             ...           ...            ...
# 9818               5             365  Private Room            1.5
# 9819               2              10   Entire Unit              1
# 9822               1              26   Entire Unit              1
# 9825               1              28   Entire Unit              1
# 9826               2            1125   Entire Unit              1
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 1                     4.99                    4.98                       5.00
# 2                     3.00                    4.00                       2.00
# 3                     5.00                    5.00                       5.00
# 4                     4.57                    5.00                       4.57
# 6                     5.00                    5.00                       5.00
# ...                    ...                     ...                        ...
# 9818                  4.86                    4.86                       5.00
# 9819                  5.00                    5.00                       5.00
# 9822                  4.90                    4.89                       4.75
# 9825                  1.00                    1.00                       1.00
# 9826                  4.75                    4.75                       4.50
#
#       review_scores_checkin  review_scores_communication  \
# 1                      4.99                         5.00
# 2                      5.00                         5.00
# 3                      5.00                         5.00
# 4                      4.71                         4.43
# 6                      4.97                         5.00
# ...                     ...                          ...
# 9818                   5.00                         4.57
# 9819                   5.00                         5.00
# 9822                   4.91                         4.95
# 9825                   1.00                         1.00
# 9826                   4.50                         4.25
#
#       review_scores_location  review_scores_value          listing_id  \
# 1                       4.97                 4.86            15239926
# 2                       4.00                 3.00            14821183
# 3                       5.00                 5.00            26296415
# 4                       4.43                 4.71            22746714
# 6                       5.00                 5.00            52992116
# ...                      ...                  ...                 ...
# 9818                    4.57                 4.86  593563874468145823
# 9819                    5.00                 5.00            16134682
# 9822                    4.73                 4.74            45361780
# 9825                    5.00                 1.00  924091269757225413
# 9826                    5.00                 4.75  720164781296601135
#
#                                                comments  \
# 1     Fantastic super hosts and space . What a beaut...
# 2     Quiet house. Bedroom is enough for sleeping. u...
# 3     Amazing experience. The house was also recentl...
# 4     Nice neighborhood and hosts. Great location. T...
# 6     Everything was great! The room was nice and cl...
# ...                                                 ...
# 9818  Great place, good communication and excellent ...
# 9819  Bella’s place is everything you see on the pic...
# 9822  The place was exactly how the owner described ...
# 9825  Since they sent me a review, I guess I’m revie...
# 9826  Great location, great host, beautiful apartmen...
#
#                                       processed_reviews
# 1     fantastic super host space beautiful place sta...
# 2              quiet house bedroom enough sleep unclean
# 3     amaze experience house also recently upgrade w...
# 4     nice neighborhood host great location host res...
# 6     everything great room nice clean describe chec...
# ...                                                 ...
# 9818  great place good communication excellent servi...
# 9819  bella place everything see picture good best s...
# 9822  place exactly owner describe beautiful locatio...
# 9825  since send review guess review confirm reserva...
# 9826  great location great host beautiful apartment ...
#
# [5239 rows x 18 columns]

# %%
#create csv of working data frame for modeling
df_merge.to_csv('../data/processed_final.csv')
